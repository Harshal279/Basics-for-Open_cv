# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv.imread('/content/lena.jpg')
# Display the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
b,g,r = cv.split(image)
#image will be in grayscale format

# %%
blank = np.zeros(image.shape[:2],dtype='uint8')
blue = cv.merge([b,blank,blank])
green = cv.merge([blank,g,blank])
red= cv.merge([blank,blank,r])

# %%
cv2_imshow(b)   # for blue colour
cv2_imshow(blue)
# Out:
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2_imshow(g)   # for green colour
cv2_imshow(green)
# Out:
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2_imshow(r) # for red colour
cv2_imshow(red)
# Out:
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
print(b.shape)           # This will show no colour channels (means one channel)
print(g.shape)           # This will show no colour channels
print(r.shape)           # This will show no colour channels
print(image.shape)       # This will show 3 colour channels (Because of three colour red green blue)
# Out:
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512, 3)

# %%
merged = cv.merge([b,g,r])   # This will merge all the bgr image above
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
